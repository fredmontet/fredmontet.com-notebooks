# %% [markdown]
# <a href="https://colab.research.google.com/github/fredmontet/fredmontet.com-notebooks/blob/master/notebooks/bbdata_workshop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Imports

# %%
from google.colab import drive
from datetime import datetime
import pandas as pd
import requests

# %% [markdown]
# # BBData Workshop
#
# BBData est une plateforme de stockage de séries temporelles. Ce genre de données est définie comme étant une suite de données. Chaque élément de cette suite est composé d'un indice temporel et d'une valeur.
#
# https://fr.wikipedia.org/wiki/S%C3%A9rie_temporelle

# %% [markdown]
# ## Concepts
#
# Quatre éléments à retenir, du côté utilisateur :
#
#   - User
#   - User Groups
#
# Et du côté capteur :
#
#   - Object Group
#   - Object
#
# ### Liens
#
# https://daplab.gitlab.io/bbdata-docs/resources/rights.png
# https://daplab.gitlab.io/bbdata-docs/conception/

# %% [markdown]
# ## Création de l'infrastructure de stockage
#
# Avant de stocker de la donnée dans BBData, il est bon de voir comment le faire avec un administrateur; Jonathan Rial ou moi. Nous sommes là pour vous aider.
#
# L'installation est simple et prend quelques minutes. Pour résumer, voici les différentes étapes:
#
# 1. Créer un User Group pour le projet en question
# 2. Associer (éventuellement créer) des utilisateurs à ce User Group
# 3. Créer un Object Group et y associer un User Group
# 4. Créer des Object et les associers à un Object Group
#
# Une fois cela fait, il est possible d'utiliser BBData pour le stockage et l'acquisition de donnée.
#
# Aussi, dans le cas ou il y a une quantité importante de capteurs, il est possible de scripter ce processus.

# %% [markdown]
# ## Stocker des données
#
# Dans cette exemple nous allons stocker un CSV de données historiques.
#
# ### Chargement des données
#
# Tout d'abord, montons le Google Drive

# %%
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %% [markdown]
# Chargons les données avec Pandas

# %%
data = pd.read_csv("/content/drive/My Drive/4652.csv")
data = data[5:100] # TODO - delete this line

# %%
data
# Out:
#                   timestamp  value
# 5   2016-11-14 15:15:04.000   2.00
# 6   2016-11-14 15:35:14.000   2.00
# 7   2016-11-14 15:45:20.000   1.92
# 8   2016-11-14 15:50:22.000   1.92
# 9   2016-11-14 15:55:26.000   1.84
# ..                      ...    ...
# 95  2016-11-14 23:14:16.000   1.28
# 96  2016-11-14 23:19:18.000   1.44
# 97  2016-11-14 23:24:22.000   1.44
# 98  2016-11-14 23:29:24.000   1.44
# 99  2016-11-14 23:34:26.000   1.28
#
# [95 rows x 2 columns]

# %%
data.timestamp = data.timestamp.apply(lambda t: datetime.strptime(t, "%Y-%m-%d %H:%M:%S.%f"))
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95 entries, 5 to 99
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   timestamp  95 non-null     datetime64[ns]
#  1   value      95 non-null     float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 1.6 KB

# %% [markdown]
# Déclarer différentes constantes

# %%
ENDPOINT = "https://bbdata-admin.smartlivinglab.ch/api/objects/values"
OBJECT_ID = 13457
TOKEN = "606bd3ee8e030a4c6fa5beaba1f17f2e"
COMMENT = ""

# %% [markdown]
# Définition d'une fonction pour convertir une ligne d'un Pandas DataFrame en un objet JSON.

# %%
def to_json(obj_data):
  return {"objectId": OBJECT_ID, "token": TOKEN, "timestamp": obj_data.timestamp.isoformat(), "value": str(obj_data.value), "comment": COMMENT}

# %% [markdown]
# Conversion du DataFrame en array d'objets JSON

# %%
json_data = [to_json(d) for _, d in data.iterrows()]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-4a70ac54c525> in <module>()
# ----> 1 json_data = [to_json(d) for _, d in data.iterrows()]
#
# <ipython-input-11-4a70ac54c525> in <listcomp>(.0)
# ----> 1 json_data = [to_json(d) for _, d in data.iterrows()]
#
# <ipython-input-9-4cb04d6ff5a6> in to_json(obj_data)
#       1 def to_json(obj_data):
# ----> 2   return {"objectId": OBJECT_ID, "token": TOKEN, "timestamp": obj_data.timestamp.isoformat(), "value": str(obj_data.value), "comment": COMMENT}
#
# AttributeError: 'str' object has no attribute 'isoformat'

# %% [markdown]
# Envois des données à l'API REST

# %%
response = requests.post(ENDPOINT, json=json_data)

# %% [markdown]
# Les données sont maintenant stockées sur BBData

# %%
print(response.text)
# Out:
# [ {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T15:15:04.000Z",
#   "value" : "2.0",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T15:35:14.000Z",
#   "value" : "2.0",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T15:45:20.000Z",
#   "value" : "1.92",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T15:50:22.000Z",
#   "value" : "1.92",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T15:55:26.000Z",
#   "value" : "1.84",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T16:00:28.000Z",
#   "value" : "1.84",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T16:05:30.000Z",
#   "value" : "1.68",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T16:10:34.000Z",
#   "value" : "1.84",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T16:15:36.000Z",
#   "value" : "1.6",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T16:20:38.000Z",
#   "value" : "1.84",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T16:26:03.000Z",
#   "value" : "1.84",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T16:30:44.000Z",
#   "value" : "1.84",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T16:35:46.000Z",
#   "value" : "1.84",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T16:40:50.000Z",
#   "value" : "1.84",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T16:45:52.000Z",
#   "value" : "1.84",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T17:09:17.000Z",
#   "value" : "1.68",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T17:09:20.000Z",
#   "value" : "1.68",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T17:09:22.000Z",
#   "value" : "1.92",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T17:11:06.000Z",
#   "value" : "1.68",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T17:16:08.000Z",
#   "value" : "1.6",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T17:21:10.000Z",
#   "value" : "1.84",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T17:26:14.000Z",
#   "value" : "1.68",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T17:31:16.000Z",
#   "value" : "1.84",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T17:36:18.000Z",
#   "value" : "1.6",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T17:41:22.000Z",
#   "value" : "1.52",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T17:46:24.000Z",
#   "value" : "1.6",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T17:51:26.000Z",
#   "value" : "1.6",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T17:56:28.000Z",
#   "value" : "1.6",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T18:01:32.000Z",
#   "value" : "1.52",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T18:06:34.000Z",
#   "value" : "1.52",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T18:11:36.000Z",
#   "value" : "1.52",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T18:16:40.000Z",
#   "value" : "1.44",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T18:21:42.000Z",
#   "value" : "1.52",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T18:26:44.000Z",
#   "value" : "1.52",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T18:31:48.000Z",
#   "value" : "1.84",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T18:36:50.000Z",
#   "value" : "1.52",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T18:41:52.000Z",
#   "value" : "1.52",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T18:46:56.000Z",
#   "value" : "1.44",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T18:51:58.000Z",
#   "value" : "1.6",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T18:57:00.000Z",
#   "value" : "1.52",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T19:02:04.000Z",
#   "value" : "1.52",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T19:07:06.000Z",
#   "value" : "1.52",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T19:12:08.000Z",
#   "value" : "1.52",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T19:17:12.000Z",
#   "value" : "1.52",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T19:22:14.000Z",
#   "value" : "1.44",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T19:27:16.000Z",
#   "value" : "1.44",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T19:32:20.000Z",
#   "value" : "1.44",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T19:37:22.000Z",
#   "value" : "1.52",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T19:42:24.000Z",
#   "value" : "1.44",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T19:47:28.000Z",
#   "value" : "1.44",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T19:52:30.000Z",
#   "value" : "1.44",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T19:57:32.000Z",
#   "value" : "1.44",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T20:02:36.000Z",
#   "value" : "1.28",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T20:07:38.000Z",
#   "value" : "1.52",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T20:12:40.000Z",
#   "value" : "1.6",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T20:17:44.000Z",
#   "value" : "1.6",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T20:22:46.000Z",
#   "value" : "1.52",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T20:27:48.000Z",
#   "value" : "1.52",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T20:32:52.000Z",
#   "value" : "1.6",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T20:37:54.000Z",
#   "value" : "1.52",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T20:42:56.000Z",
#   "value" : "1.52",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T20:48:00.000Z",
#   "value" : "1.44",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T20:53:02.000Z",
#   "value" : "1.44",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T20:58:04.000Z",
#   "value" : "1.28",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T21:03:08.000Z",
#   "value" : "1.28",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T21:08:10.000Z",
#   "value" : "1.28",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T21:13:12.000Z",
#   "value" : "1.2",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T21:18:14.000Z",
#   "value" : "1.2",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T21:23:18.000Z",
#   "value" : "1.28",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T21:28:20.000Z",
#   "value" : "1.44",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T21:33:22.000Z",
#   "value" : "1.28",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T21:38:26.000Z",
#   "value" : "1.28",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T21:43:28.000Z",
#   "value" : "1.2",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T21:48:30.000Z",
#   "value" : "1.2",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T21:53:34.000Z",
#   "value" : "1.2",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T21:58:36.000Z",
#   "value" : "1.2",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T22:03:38.000Z",
#   "value" : "1.28",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T22:08:42.000Z",
#   "value" : "1.28",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T22:13:44.000Z",
#   "value" : "1.44",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T22:18:46.000Z",
#   "value" : "1.2",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T22:23:50.000Z",
#   "value" : "1.28",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T22:28:52.000Z",
#   "value" : "1.2",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T22:33:54.000Z",
#   "value" : "1.2",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T22:38:58.000Z",
#   "value" : "1.2",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T22:44:00.000Z",
#   "value" : "1.44",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T22:49:02.000Z",
#   "value" : "1.44",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T22:54:06.000Z",
#   "value" : "1.44",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T22:59:08.000Z",
#   "value" : "1.28",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T23:04:10.000Z",
#   "value" : "1.28",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T23:09:14.000Z",
#   "value" : "1.28",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T23:14:16.000Z",
#   "value" : "1.28",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T23:19:18.000Z",
#   "value" : "1.44",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T23:24:22.000Z",
#   "value" : "1.44",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T23:29:24.000Z",
#   "value" : "1.44",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# }, {
#   "objectId" : 13457,
#   "timestamp" : "2016-11-14T23:34:26.000Z",
#   "value" : "1.28",
#   "comment" : "",
#   "unitName" : "none",
#   "unitSymbol" : " ",
#   "type" : "string",
#   "owner" : 56
# } ]

# %% [markdown]
# ## Récuperer des données
#
# Mettre de la donnée sur la plateforme permet d'assurer sa pérénité mais il s'agit aussi d'utiliser ces données. Pour cela, le processus est le suivant:

# %% [markdown]
# 1. Se loguer

# %%
ENDPOINT = f"https://bbdata-admin.smartlivinglab.ch/api/login"
USERNAME = "john.smith"
PASSWORD = "admin1234"

# %%
creds = {"username": USERNAME, "password": PASSWORD}

# %%
response = requests.post(ENDPOINT, json=creds)
response.json()
# Out:
# {'description': 'auto_login',
#  'expirationDate': '2020-11-04T10:15:54.581Z',
#  'id': 1967766,
#  'readOnly': False,
#  'secret': '5767aebea82411f4a9a536758bae9370',
#  'userId': 108}

# %% [markdown]
# 2. Copier son API key

# %%
# /!\ both parameters must be strings!

USER_ID = str(response.json()["userId"])
API_KEY = str(response.json()["secret"])

headers = {
    'bbuser' : USER_ID,
    'bbtoken' :  API_KEY
}

# %%
ENDPOINT = f"https://bbdata-admin.smartlivinglab.ch/api/me"
response = requests.get(ENDPOINT, headers=headers)
response.json()
# Out:
# {'creationdate': '2020-11-03T20:20:54.000Z', 'id': 108, 'name': 'john.smith'}

# %% [markdown]
# 3. Récuperer ses données

# %%
# ⚠️ les timestamps sont en UTC ISO-8601
from_timestamp = "2016-01-01T00:00:00.000Z"
to_timestamp = "2016-12-01T00:00:00.000Z"

ENDPOINT = f"https://bbdata-admin.smartlivinglab.ch/api/objects/{OBJECT_ID}/values?from={from_timestamp}&to={to_timestamp}"
response = requests.get(ENDPOINT, headers=headers)
response.json()
# Out:
# [{'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-02-14T14:03:33.000Z',
#   'value': '6.8'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-01T04:15:20.000Z',
#   'value': '1.52'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T06:57:36.000Z',
#   'value': '9.84'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T14:44:48.000Z',
#   'value': '2.08'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T15:10:02.000Z',
#   'value': '1.92'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T15:15:04.000Z',
#   'value': '2.0'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T15:35:14.000Z',
#   'value': '2.0'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T15:45:20.000Z',
#   'value': '1.92'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T15:50:22.000Z',
#   'value': '1.92'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T15:55:26.000Z',
#   'value': '1.84'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T16:00:28.000Z',
#   'value': '1.84'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T16:05:30.000Z',
#   'value': '1.68'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T16:10:34.000Z',
#   'value': '1.84'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T16:15:36.000Z',
#   'value': '1.6'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T16:20:38.000Z',
#   'value': '1.84'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T16:26:03.000Z',
#   'value': '1.84'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T16:30:44.000Z',
#   'value': '1.84'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T16:35:46.000Z',
#   'value': '1.84'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T16:40:50.000Z',
#   'value': '1.84'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T16:45:52.000Z',
#   'value': '1.84'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T17:09:17.000Z',
#   'value': '1.68'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T17:09:20.000Z',
#   'value': '1.68'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T17:09:22.000Z',
#   'value': '1.92'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T17:11:06.000Z',
#   'value': '1.68'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T17:16:08.000Z',
#   'value': '1.6'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T17:21:10.000Z',
#   'value': '1.84'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T17:26:14.000Z',
#   'value': '1.68'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T17:31:16.000Z',
#   'value': '1.84'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T17:36:18.000Z',
#   'value': '1.6'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T17:41:22.000Z',
#   'value': '1.52'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T17:46:24.000Z',
#   'value': '1.6'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T17:51:26.000Z',
#   'value': '1.6'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T17:56:28.000Z',
#   'value': '1.6'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T18:01:32.000Z',
#   'value': '1.52'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T18:06:34.000Z',
#   'value': '1.52'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T18:11:36.000Z',
#   'value': '1.52'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T18:16:40.000Z',
#   'value': '1.44'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T18:21:42.000Z',
#   'value': '1.52'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T18:26:44.000Z',
#   'value': '1.52'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T18:31:48.000Z',
#   'value': '1.84'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T18:36:50.000Z',
#   'value': '1.52'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T18:41:52.000Z',
#   'value': '1.52'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T18:46:56.000Z',
#   'value': '1.44'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T18:51:58.000Z',
#   'value': '1.6'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T18:57:00.000Z',
#   'value': '1.52'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T19:02:04.000Z',
#   'value': '1.52'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T19:07:06.000Z',
#   'value': '1.52'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T19:12:08.000Z',
#   'value': '1.52'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T19:17:12.000Z',
#   'value': '1.52'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T19:22:14.000Z',
#   'value': '1.44'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T19:27:16.000Z',
#   'value': '1.44'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T19:32:20.000Z',
#   'value': '1.44'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T19:37:22.000Z',
#   'value': '1.52'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T19:42:24.000Z',
#   'value': '1.44'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T19:47:28.000Z',
#   'value': '1.44'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T19:52:30.000Z',
#   'value': '1.44'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T19:57:32.000Z',
#   'value': '1.44'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T20:02:36.000Z',
#   'value': '1.28'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T20:07:38.000Z',
#   'value': '1.52'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T20:12:40.000Z',
#   'value': '1.6'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T20:17:44.000Z',
#   'value': '1.6'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T20:22:46.000Z',
#   'value': '1.52'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T20:27:48.000Z',
#   'value': '1.52'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T20:32:52.000Z',
#   'value': '1.6'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T20:37:54.000Z',
#   'value': '1.52'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T20:42:56.000Z',
#   'value': '1.52'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T20:48:00.000Z',
#   'value': '1.44'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T20:53:02.000Z',
#   'value': '1.44'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T20:58:04.000Z',
#   'value': '1.28'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T21:03:08.000Z',
#   'value': '1.28'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T21:08:10.000Z',
#   'value': '1.28'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T21:13:12.000Z',
#   'value': '1.2'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T21:18:14.000Z',
#   'value': '1.2'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T21:23:18.000Z',
#   'value': '1.28'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T21:28:20.000Z',
#   'value': '1.44'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T21:33:22.000Z',
#   'value': '1.28'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T21:38:26.000Z',
#   'value': '1.28'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T21:43:28.000Z',
#   'value': '1.2'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T21:48:30.000Z',
#   'value': '1.2'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T21:53:34.000Z',
#   'value': '1.2'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T21:58:36.000Z',
#   'value': '1.2'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T22:03:38.000Z',
#   'value': '1.28'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T22:08:42.000Z',
#   'value': '1.28'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T22:13:44.000Z',
#   'value': '1.44'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T22:18:46.000Z',
#   'value': '1.2'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T22:23:50.000Z',
#   'value': '1.28'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T22:28:52.000Z',
#   'value': '1.2'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T22:33:54.000Z',
#   'value': '1.2'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T22:38:58.000Z',
#   'value': '1.2'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T22:44:00.000Z',
#   'value': '1.44'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T22:49:02.000Z',
#   'value': '1.44'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T22:54:06.000Z',
#   'value': '1.44'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T22:59:08.000Z',
#   'value': '1.28'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T23:04:10.000Z',
#   'value': '1.28'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T23:09:14.000Z',
#   'value': '1.28'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T23:14:16.000Z',
#   'value': '1.28'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T23:19:18.000Z',
#   'value': '1.44'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T23:24:22.000Z',
#   'value': '1.44'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T23:29:24.000Z',
#   'value': '1.44'},
#  {'comment': '',
#   'objectId': 13457,
#   'timestamp': '2016-11-14T23:34:26.000Z',
#   'value': '1.28'}]

# %%
df = pd.DataFrame(response.json())
df['timestamp'] = pd.to_datetime(df['timestamp'])
df = df.astype({'value': 'float64'})
df = df.set_index("timestamp")

# %%
df["2016-11-14 16:00":"2016-11-14 22:00"]["value"].plot();

# %% [markdown]
# Done!
#
# Avec ça, vous êtes prêt pour stocker et récuperer les données de n'importe quel capteur!
#
# Si vous avez des questions n'hésitez pas à contacter :
#
# - Frédéric Montet (frederic.montet@hefr.ch)
# - Jonathan Rial (jonathan.rial@hefr.ch)

# %% [markdown]
# ## Liens utiles
#
# - https://bbdata.smartlivinglab.ch/
# - https://bbdata-admin.smartlivinglab.ch/
# - https://daplab.gitlab.io/bbdata-docs/
# - https://bbdata.smartlivinglab.ch/docs/swagger-ui/index.html?configUrl=/docs/api/bbdata/swagger-config#/
# - https://github.com/fredmontet/fredmontet.com-notebooks/blob/master/notebooks/bbdata_workshop.ipynb
